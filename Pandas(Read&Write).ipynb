# %%
import pandas as pd
import numpy as ny
import os

# %% [markdown]
# # Read

# %% [markdown]
# # Read a file from PC

# %%
df=pd.read_csv("C:\\Users\\amanm\\OneDrive\\Desktop\\titanic\\test.csv")
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %% [markdown]
# # Read from your notebook

# %%
df2=pd.read_csv("data.csv")
df2
# Out:
#               ISIN     SYMBOL SERIES TYPE  HAIRCUT     NAV
# 0     INF209K01ME4      B501G     GR  GMF     10.0  561.66
# 1     INF209K01RU9      B153G     GR  GMF     10.0  346.11
# 2     INF209K01VA3     B153GZ     GR  GMF     10.0  349.00
# 3     INF209K01UZ2     B153DZ     DP  GMF     10.0  100.20
# 4     INF209K01VC9     B153WZ     DP  GMF     10.0  100.23
# ...            ...        ...    ...  ...      ...     ...
# 2909  INF740K01LP6    DSPUFEG     GR  OMF      7.5   42.31
# 2910  INF740K01LQ4   DSPUFEDP     DP  OMF      7.5   23.49
# 2911  INF740K01OH7  DSPUFEDGR     GR  OMF      7.5   45.25
# 2912  INF740K01OI5  DSPUFEDDP     DP  OMF      7.5   42.02
# 2913  INF740K01OJ3  DSPUFEDDR     DR  OMF      7.5   42.02
#
# [2914 rows x 6 columns]

# %% [markdown]
# # Some Parameters

# %% [markdown]
# 1. know about directory.

# %%
os.getcwd()
# Out:
# 'C:\\Users\\amanm\\Downloads'

# %% [markdown]
# 2. Select the number of rows

# %%
df2=pd.read_csv("data.csv", nrows=2)
df2
# Out:
#            ISIN SYMBOL SERIES TYPE  HAIRCUT     NAV
# 0  INF209K01ME4  B501G     GR  GMF       10  561.66
# 1  INF209K01RU9  B153G     GR  GMF       10  346.11

# %% [markdown]
# 3. Select the number of columns.

# %%
df2=pd.read_csv("data.csv", usecols=[0,1])
df2
# Out:
#               ISIN     SYMBOL
# 0     INF209K01ME4      B501G
# 1     INF209K01RU9      B153G
# 2     INF209K01VA3     B153GZ
# 3     INF209K01UZ2     B153DZ
# 4     INF209K01VC9     B153WZ
# ...            ...        ...
# 2909  INF740K01LP6    DSPUFEG
# 2910  INF740K01LQ4   DSPUFEDP
# 2911  INF740K01OH7  DSPUFEDGR
# 2912  INF740K01OI5  DSPUFEDDP
# 2913  INF740K01OJ3  DSPUFEDDR
#
# [2914 rows x 2 columns]

# %% [markdown]
# 4. Select the number of rows and columns.

# %%
df2=pd.read_csv("data.csv", nrows=2,usecols=[1,3])
df2
# Out:
#   SYMBOL TYPE
# 0  B501G  GMF
# 1  B153G  GMF

# %% [markdown]
# 5. Skip the rows.

# %%
df2=pd.read_csv("data.csv",skiprows=[1,4])
df2
# Out:
#               ISIN     SYMBOL SERIES TYPE  HAIRCUT     NAV
# 0     INF209K01RU9      B153G     GR  GMF     10.0  346.11
# 1     INF209K01VA3     B153GZ     GR  GMF     10.0  349.00
# 2     INF209K01VC9     B153WZ     DP  GMF     10.0  100.23
# 3     INF209K01VD7      B153Z     DP  GMF     10.0  189.48
# 4     INF740K01714   DSPBRTBF     GR  GMF     10.0   43.20
# ...            ...        ...    ...  ...      ...     ...
# 2907  INF740K01LP6    DSPUFEG     GR  OMF      7.5   42.31
# 2908  INF740K01LQ4   DSPUFEDP     DP  OMF      7.5   23.49
# 2909  INF740K01OH7  DSPUFEDGR     GR  OMF      7.5   45.25
# 2910  INF740K01OI5  DSPUFEDDP     DP  OMF      7.5   42.02
# 2911  INF740K01OJ3  DSPUFEDDR     DR  OMF      7.5   42.02
#
# [2912 rows x 6 columns]

# %% [markdown]
# 6. Make index of any column by Name.

# %%
df2=pd.read_csv("data.csv", index_col="ISIN")
df2
# Out:
#                  SYMBOL SERIES TYPE  HAIRCUT     NAV
# ISIN
# INF209K01ME4      B501G     GR  GMF     10.0  561.66
# INF209K01RU9      B153G     GR  GMF     10.0  346.11
# INF209K01VA3     B153GZ     GR  GMF     10.0  349.00
# INF209K01UZ2     B153DZ     DP  GMF     10.0  100.20
# INF209K01VC9     B153WZ     DP  GMF     10.0  100.23
# ...                 ...    ...  ...      ...     ...
# INF740K01LP6    DSPUFEG     GR  OMF      7.5   42.31
# INF740K01LQ4   DSPUFEDP     DP  OMF      7.5   23.49
# INF740K01OH7  DSPUFEDGR     GR  OMF      7.5   45.25
# INF740K01OI5  DSPUFEDDP     DP  OMF      7.5   42.02
# INF740K01OJ3  DSPUFEDDR     DR  OMF      7.5   42.02
#
# [2914 rows x 5 columns]

# %% [markdown]
# 7. Make index by column index number.

# %%
df2=pd.read_csv("data.csv", index_col=2)
df2
# Out:
#                 ISIN     SYMBOL TYPE  HAIRCUT     NAV
# SERIES
# GR      INF209K01ME4      B501G  GMF     10.0  561.66
# GR      INF209K01RU9      B153G  GMF     10.0  346.11
# GR      INF209K01VA3     B153GZ  GMF     10.0  349.00
# DP      INF209K01UZ2     B153DZ  GMF     10.0  100.20
# DP      INF209K01VC9     B153WZ  GMF     10.0  100.23
# ...              ...        ...  ...      ...     ...
# GR      INF740K01LP6    DSPUFEG  OMF      7.5   42.31
# DP      INF740K01LQ4   DSPUFEDP  OMF      7.5   23.49
# GR      INF740K01OH7  DSPUFEDGR  OMF      7.5   45.25
# DP      INF740K01OI5  DSPUFEDDP  OMF      7.5   42.02
# DR      INF740K01OJ3  DSPUFEDDR  OMF      7.5   42.02
#
# [2914 rows x 5 columns]

# %% [markdown]
# 8. Make head by any row.

# %%
df2=pd.read_csv("data.csv",header=1)
df2
# Out:
#       INF209K01ME4      B501G  GR  GMF    10  561.66
# 0     INF209K01RU9      B153G  GR  GMF  10.0  346.11
# 1     INF209K01VA3     B153GZ  GR  GMF  10.0  349.00
# 2     INF209K01UZ2     B153DZ  DP  GMF  10.0  100.20
# 3     INF209K01VC9     B153WZ  DP  GMF  10.0  100.23
# 4     INF209K01VD7      B153Z  DP  GMF  10.0  189.48
# ...            ...        ...  ..  ...   ...     ...
# 2908  INF740K01LP6    DSPUFEG  GR  OMF   7.5   42.31
# 2909  INF740K01LQ4   DSPUFEDP  DP  OMF   7.5   23.49
# 2910  INF740K01OH7  DSPUFEDGR  GR  OMF   7.5   45.25
# 2911  INF740K01OI5  DSPUFEDDP  DP  OMF   7.5   42.02
# 2912  INF740K01OJ3  DSPUFEDDR  DR  OMF   7.5   42.02
#
# [2913 rows x 6 columns]

# %% [markdown]
# 9. Make integer as head.

# %%
df2=pd.read_csv("data.csv", header=None)
df2
# Out:
#                  0          1       2     3        4       5
# 0             ISIN     SYMBOL  SERIES  TYPE  HAIRCUT     NAV
# 1     INF209K01ME4      B501G      GR   GMF       10  561.66
# 2     INF209K01RU9      B153G      GR   GMF       10  346.11
# 3     INF209K01VA3     B153GZ      GR   GMF       10     349
# 4     INF209K01UZ2     B153DZ      DP   GMF       10   100.2
# ...            ...        ...     ...   ...      ...     ...
# 2910  INF740K01LP6    DSPUFEG      GR   OMF      7.5   42.31
# 2911  INF740K01LQ4   DSPUFEDP      DP   OMF      7.5   23.49
# 2912  INF740K01OH7  DSPUFEDGR      GR   OMF      7.5   45.25
# 2913  INF740K01OI5  DSPUFEDDP      DP   OMF      7.5   42.02
# 2914  INF740K01OJ3  DSPUFEDDR      DR   OMF      7.5   42.02
#
# [2915 rows x 6 columns]

# %% [markdown]
# 10. Make header by Names.

# %%
df2=pd.read_csv("data.csv", names=["A","B","C","D","E","F"])
df2
# Out:
#                  A          B       C     D        E       F
# 0             ISIN     SYMBOL  SERIES  TYPE  HAIRCUT     NAV
# 1     INF209K01ME4      B501G      GR   GMF       10  561.66
# 2     INF209K01RU9      B153G      GR   GMF       10  346.11
# 3     INF209K01VA3     B153GZ      GR   GMF       10     349
# 4     INF209K01UZ2     B153DZ      DP   GMF       10   100.2
# ...            ...        ...     ...   ...      ...     ...
# 2910  INF740K01LP6    DSPUFEG      GR   OMF      7.5   42.31
# 2911  INF740K01LQ4   DSPUFEDP      DP   OMF      7.5   23.49
# 2912  INF740K01OH7  DSPUFEDGR      GR   OMF      7.5   45.25
# 2913  INF740K01OI5  DSPUFEDDP      DP   OMF      7.5   42.02
# 2914  INF740K01OJ3  DSPUFEDDR      DR   OMF      7.5   42.02
#
# [2915 rows x 6 columns]
